# %%
pip install pandas
# Out:
# ...
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/home/a3-402-21/jupyter/environment/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install numpy
# Out:
# ...
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/home/a3-402-21/jupyter/environment/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Importing required libraries and dataset

# %%
import pandas as pd
import numpy as num

# %%
df = pd.read_csv('city_day.csv')

# %%
df
# Out:
#                 City        Date  PM2.5   PM10     NO    NO2    NOx    NH3  \
# 0          Ahmedabad  2015-01-01    NaN    NaN   0.92  18.22  17.15    NaN
# 1          Ahmedabad  2015-01-02    NaN    NaN   0.97  15.69  16.46    NaN
# 2          Ahmedabad  2015-01-03    NaN    NaN  17.40  19.30  29.70    NaN
# 3          Ahmedabad  2015-01-04    NaN    NaN   1.70  18.48  17.97    NaN
# 4          Ahmedabad  2015-01-05    NaN    NaN  22.10  21.42  37.76    NaN
# ...              ...         ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  2020-06-27  15.02  50.94   7.68  25.06  19.54  12.47
# 29527  Visakhapatnam  2020-06-28  24.38  74.09   3.42  26.06  16.53  11.99
# 29528  Visakhapatnam  2020-06-29  22.91  65.73   3.45  29.53  18.33  10.71
# 29529  Visakhapatnam  2020-06-30  16.64  49.97   4.05  29.26  18.80  10.03
# 29530  Visakhapatnam  2020-07-01  15.00  66.00   0.40  26.85  14.05   5.20
#
# ...

# %% [markdown]
# ## 1. Data Cleaning

# %%
df_year = pd.DatetimeIndex(df['Date']).year
df_year
# Out:
# Int64Index([2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015, 2015,
#             ...
#             2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020, 2020],
#            dtype='int64', name='Date', length=29531)

# %%
df_month = pd.DatetimeIndex(df['Date']).month

# %%
df.drop(['Date'], inplace=True, axis=1)
df
# Out:
#                 City  PM2.5   PM10     NO    NO2    NOx    NH3     CO    SO2  \
# 0          Ahmedabad    NaN    NaN   0.92  18.22  17.15    NaN   0.92  27.64
# 1          Ahmedabad    NaN    NaN   0.97  15.69  16.46    NaN   0.97  24.55
# 2          Ahmedabad    NaN    NaN  17.40  19.30  29.70    NaN  17.40  29.07
# 3          Ahmedabad    NaN    NaN   1.70  18.48  17.97    NaN   1.70  18.59
# 4          Ahmedabad    NaN    NaN  22.10  21.42  37.76    NaN  22.10  39.33
# ...              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  15.02  50.94   7.68  25.06  19.54  12.47   0.47   8.55
# 29527  Visakhapatnam  24.38  74.09   3.42  26.06  16.53  11.99   0.52  12.72
# 29528  Visakhapatnam  22.91  65.73   3.45  29.53  18.33  10.71   0.48   8.42
# 29529  Visakhapatnam  16.64  49.97   4.05  29.26  18.80  10.03   0.52   9.84
# 29530  Visakhapatnam  15.00  66.00   0.40  26.85  14.05   5.20   0.59   2.10
#
# ...

# %% [markdown]
# ## 2.Integration data

# %%
df['Year'] = df_year
df
# Out:
#                 City  PM2.5   PM10     NO    NO2    NOx    NH3     CO    SO2  \
# 0          Ahmedabad    NaN    NaN   0.92  18.22  17.15    NaN   0.92  27.64
# 1          Ahmedabad    NaN    NaN   0.97  15.69  16.46    NaN   0.97  24.55
# 2          Ahmedabad    NaN    NaN  17.40  19.30  29.70    NaN  17.40  29.07
# 3          Ahmedabad    NaN    NaN   1.70  18.48  17.97    NaN   1.70  18.59
# 4          Ahmedabad    NaN    NaN  22.10  21.42  37.76    NaN  22.10  39.33
# ...              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  15.02  50.94   7.68  25.06  19.54  12.47   0.47   8.55
# 29527  Visakhapatnam  24.38  74.09   3.42  26.06  16.53  11.99   0.52  12.72
# 29528  Visakhapatnam  22.91  65.73   3.45  29.53  18.33  10.71   0.48   8.42
# 29529  Visakhapatnam  16.64  49.97   4.05  29.26  18.80  10.03   0.52   9.84
# 29530  Visakhapatnam  15.00  66.00   0.40  26.85  14.05   5.20   0.59   2.10
#
# ...

# %%
df['Month'] = df_month
df
# Out:
#                 City  PM2.5   PM10     NO    NO2    NOx    NH3     CO    SO2  \
# 0          Ahmedabad    NaN    NaN   0.92  18.22  17.15    NaN   0.92  27.64
# 1          Ahmedabad    NaN    NaN   0.97  15.69  16.46    NaN   0.97  24.55
# 2          Ahmedabad    NaN    NaN  17.40  19.30  29.70    NaN  17.40  29.07
# 3          Ahmedabad    NaN    NaN   1.70  18.48  17.97    NaN   1.70  18.59
# 4          Ahmedabad    NaN    NaN  22.10  21.42  37.76    NaN  22.10  39.33
# ...              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  15.02  50.94   7.68  25.06  19.54  12.47   0.47   8.55
# 29527  Visakhapatnam  24.38  74.09   3.42  26.06  16.53  11.99   0.52  12.72
# 29528  Visakhapatnam  22.91  65.73   3.45  29.53  18.33  10.71   0.48   8.42
# 29529  Visakhapatnam  16.64  49.97   4.05  29.26  18.80  10.03   0.52   9.84
# 29530  Visakhapatnam  15.00  66.00   0.40  26.85  14.05   5.20   0.59   2.10
#
# ...

# %% [markdown]
# ## 3. Data Transformation

# %%
df['Month_Name'] = pd.to_datetime(df['Month'], format='%m').dt.month_name().str.slice(stop=3)

# %%
df
# Out:
#                 City  PM2.5   PM10     NO    NO2    NOx    NH3     CO    SO2  \
# 0          Ahmedabad    NaN    NaN   0.92  18.22  17.15    NaN   0.92  27.64
# 1          Ahmedabad    NaN    NaN   0.97  15.69  16.46    NaN   0.97  24.55
# 2          Ahmedabad    NaN    NaN  17.40  19.30  29.70    NaN  17.40  29.07
# 3          Ahmedabad    NaN    NaN   1.70  18.48  17.97    NaN   1.70  18.59
# 4          Ahmedabad    NaN    NaN  22.10  21.42  37.76    NaN  22.10  39.33
# ...              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  15.02  50.94   7.68  25.06  19.54  12.47   0.47   8.55
# 29527  Visakhapatnam  24.38  74.09   3.42  26.06  16.53  11.99   0.52  12.72
# 29528  Visakhapatnam  22.91  65.73   3.45  29.53  18.33  10.71   0.48   8.42
# 29529  Visakhapatnam  16.64  49.97   4.05  29.26  18.80  10.03   0.52   9.84
# 29530  Visakhapatnam  15.00  66.00   0.40  26.85  14.05   5.20   0.59   2.10
#
# ...

# %%
df_grouped = df.groupby(['Year', 'Month_Name'])['AQI'].mean()

# %%
df_grouped
# Out:
# Year  Month_Name
# 2015  Apr           192.224852
#       Aug           156.327957
#       Dec           251.338798
#       Feb           418.830189
#       Jan           343.000000
#                        ...
# 2020  Jan           168.486563
#       Jul            72.500000
#       Jun            76.214674
#       Mar           110.177267
#       May            87.446292
# Name: AQI, Length: 67, dtype: float64

# %%
df
# Out:
#                 City  PM2.5   PM10     NO    NO2    NOx    NH3     CO    SO2  \
# 0          Ahmedabad    NaN    NaN   0.92  18.22  17.15    NaN   0.92  27.64
# 1          Ahmedabad    NaN    NaN   0.97  15.69  16.46    NaN   0.97  24.55
# 2          Ahmedabad    NaN    NaN  17.40  19.30  29.70    NaN  17.40  29.07
# 3          Ahmedabad    NaN    NaN   1.70  18.48  17.97    NaN   1.70  18.59
# 4          Ahmedabad    NaN    NaN  22.10  21.42  37.76    NaN  22.10  39.33
# ...              ...    ...    ...    ...    ...    ...    ...    ...    ...
# 29526  Visakhapatnam  15.02  50.94   7.68  25.06  19.54  12.47   0.47   8.55
# 29527  Visakhapatnam  24.38  74.09   3.42  26.06  16.53  11.99   0.52  12.72
# 29528  Visakhapatnam  22.91  65.73   3.45  29.53  18.33  10.71   0.48   8.42
# 29529  Visakhapatnam  16.64  49.97   4.05  29.26  18.80  10.03   0.52   9.84
# 29530  Visakhapatnam  15.00  66.00   0.40  26.85  14.05   5.20   0.59   2.10
#
# ...

# %%
df_grouped
# Out:
# Year  Month_Name
# 2015  Apr           192.224852
#       Aug           156.327957
#       Dec           251.338798
#       Feb           418.830189
#       Jan           343.000000
#                        ...
# 2020  Jan           168.486563
#       Jul            72.500000
#       Jun            76.214674
#       Mar           110.177267
#       May            87.446292
# Name: AQI, Length: 67, dtype: float64

# %% [markdown]
# ## 4. Error  Correcting

# %%
df.isna().sum()
# Out:
# City              0
# PM2.5          4598
# PM10          11140
# NO             3582
# NO2            3585
# NOx            4185
# NH3           10328
# CO             2059
# SO2            3854
# O3             4022
# Benzene        5623
# Toluene        8041
# Xylene        18109
# AQI            4681
# AQI_Bucket     4681
# Year              0
# Month             0
# Month_Name        0
# dtype: int64

# %%
df_corrected = df.fillna(df.mean())NaN
# Out:
# /tmp/ipykernel_3188/3436196788.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   df_corrected = df.fillna(df.mean())

# %%
df
df['PM2.5'].mean()
# Out:
# 67.45057794890306

# %%
# df_corrected
df_corrected['AQI'].mean()
# Out:
# 166.46358148893358

# %%
df_corrected['PM2.5'].mean()
# Out:
# 67.45057794890306

# %%
df_corrected.isna().sum()
# Out:
# City             0
# PM2.5            0
# PM10             0
# NO               0
# NO2              0
# NOx              0
# NH3              0
# CO               0
# SO2              0
# O3               0
# Benzene          0
# Toluene          0
# Xylene           0
# AQI              0
# AQI_Bucket    4681
# Year             0
# Month            0
# Month_Name       0
# dtype: int64

# %%
df.shape
# Out:
# (29531, 18)

# %%
AQI_Bucket_Distribution = df_corrected.AQI_Bucket.value_counts()
AQI_Bucket_Distribution
# Out:
# Moderate        8829
# Satisfactory    8224
# Poor            2781
# Very Poor       2337
# Good            1341
# Severe          1338
# Name: AQI_Bucket, dtype: int64

# %%
df_corrected.dropna(subset=['AQI_Bucket'], inplace=True)

# %%
AQI_Bucket_Distribution = df_corrected.AQI_Bucket.value_counts()
AQI_Bucket_Distribution
# Out:
# Moderate        8829
# Satisfactory    8224
# Poor            2781
# Very Poor       2337
# Good            1341
# Severe          1338
# Name: AQI_Bucket, dtype: int64

# %%
df.shape
# Out:
# (24850, 18)

# %%
df_corrected
# Out:
#                 City   PM2.5        PM10     NO    NO2    NOx        NH3  \
# 28         Ahmedabad   83.13  118.127103   6.93  28.71  33.72  23.483476
# 29         Ahmedabad   79.84  118.127103  13.85  28.68  41.08  23.483476
# 30         Ahmedabad   94.52  118.127103  24.39  32.66  52.61  23.483476
# 31         Ahmedabad  135.99  118.127103  43.48  42.08  84.57  23.483476
# 32         Ahmedabad  178.33  118.127103  54.56  35.31  72.80  23.483476
# ...              ...     ...         ...    ...    ...    ...        ...
# 29526  Visakhapatnam   15.02   50.940000   7.68  25.06  19.54  12.470000
# 29527  Visakhapatnam   24.38   74.090000   3.42  26.06  16.53  11.990000
# 29528  Visakhapatnam   22.91   65.730000   3.45  29.53  18.33  10.710000
# 29529  Visakhapatnam   16.64   49.970000   4.05  29.26  18.80  10.030000
# 29530  Visakhapatnam   15.00   66.000000   0.40  26.85  14.05   5.200000
#
#           CO    SO2      O3  Benzene    Toluene     Xylene    AQI  \
# ...

# %% [markdown]
# ## 5. Data Model Building

# %%
pip install DecisionTree
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 335.3/335.3 KB 1.2 MB/s eta 0:00:000:00:01m eta 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for DecisionTree: filename=DecisionTree-3.4.3-py3-none-any.whl size=81844 sha256=a00505290a472cfff6c2bd87f22021f3099df2941dc22269fb4dd174e3777f01
#   Stored in directory: /home/a3-402-21/.cache/pip/wheels/6b/0f/8f/433fa867b446f25532b21dea6d4f45e5eee707510cf7a5189a
# Successfully built DecisionTree
# ...
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/home/a3-402-21/jupyter/environment/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sklearn
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.7/26.7 MB 1.6 MB/s eta 0:00:00m eta 0:00:010:00:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 KB 1.5 MB/s eta 0:00:001.8 MB/s eta 0:00:01
# ...
#   Created wheel for sklearn: filename=sklearn-0.0-py2.py3-none-any.whl size=1310 sha256=4f6cbfaae3e7ab2d0b55a2fdb815ea323e857fa07c6467618e15e5a9317da34f
#   Stored in directory: /home/a3-402-21/.cache/pip/wheels/22/0b/40/fd3f795caaa1fb4c6cb738bc1f56100be1e57da95849bfc897
# Successfully built sklearn
# ...
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/home/a3-402-21/jupyter/environment/bin/python -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import accuracy_score

# %%
df_corrected
# Out:
#                 City   PM2.5        PM10     NO    NO2    NOx        NH3  \
# 28         Ahmedabad   83.13  118.127103   6.93  28.71  33.72  23.483476
# 29         Ahmedabad   79.84  118.127103  13.85  28.68  41.08  23.483476
# 30         Ahmedabad   94.52  118.127103  24.39  32.66  52.61  23.483476
# 31         Ahmedabad  135.99  118.127103  43.48  42.08  84.57  23.483476
# 32         Ahmedabad  178.33  118.127103  54.56  35.31  72.80  23.483476
# ...              ...     ...         ...    ...    ...    ...        ...
# 29526  Visakhapatnam   15.02   50.940000   7.68  25.06  19.54  12.470000
# 29527  Visakhapatnam   24.38   74.090000   3.42  26.06  16.53  11.990000
# 29528  Visakhapatnam   22.91   65.730000   3.45  29.53  18.33  10.710000
# 29529  Visakhapatnam   16.64   49.970000   4.05  29.26  18.80  10.030000
# 29530  Visakhapatnam   15.00   66.000000   0.40  26.85  14.05   5.200000
#
#           CO    SO2      O3  Benzene    Toluene     Xylene    AQI  \
# ...

# %%
X = df_corrected[['Month','Year']]
y = df_corrected['AQI']

# %%
X.head()
# Out:
#     Month  Year
# 28      1  2015
# 29      1  2015
# 30      1  2015
# 31      2  2015
# 32      2  2015

# %%
y.head()
# Out:
# 28    209.0
# 29    328.0
# 30    514.0
# 31    782.0
# 32    914.0
# Name: AQI, dtype: float64

# %%
test_size = 0.5
seed = 5
X_train, X_test, y_train, y_test = train_test_split(X,y,test_size=test_size, random_state=seed)

# %%
X_train
# Out:
#        Month  Year
# 20090      9  2015
# 26352     11  2018
# 23417      4  2019
# 9475       6  2019
# 20162     11  2015
# ...      ...   ...
# 28060      6  2020
# 3918       6  2019
# 24205      5  2016
# 21003      3  2018
# 3786       2  2019
#
# [12425 rows x 2 columns]

# %%
X_test
# Out:
#        Month  Year
# 10563     12  2015
# 6842       8  2018
# 7352       1  2020
# 29118      5  2019
# 20911     12  2017
# ...      ...   ...
# 6393      12  2019
# 1535       3  2019
# 13205      2  2018
# 18165      7  2018
# 25000      7  2018
#
# [12425 rows x 2 columns]

# %%
y_train
# Out:
# 20090     86.0
# 26352    192.0
# 23417     96.0
# 9475     123.0
# 20162    482.0
#          ...
# 28060     50.0
# 3918      94.0
# 24205    233.0
# 21003    202.0
# 3786     126.0
# Name: AQI, Length: 12425, dtype: float64

# %%
y_test
# Out:
# 10563    400.0
# 6842      54.0
# 7352     108.0
# 29118    111.0
# 20911    434.0
#          ...
# 6393     137.0
# 1535     625.0
# 13205    345.0
# 18165     76.0
# 25000     99.0
# Name: AQI, Length: 12425, dtype: float64

# %%
# Select algorithm
model = DecisionTreeClassifier()

# %%
model.fit(X_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
prediction = model.predict(X_train)

# %%
print(accuracy_score(y_train, prediction)*100,"%")
# Out:
# 2.7686116700201207 %
