# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
Air = pd.read_csv(r'/home/pict/Downloads/AirQualityUCI.csv', sep = ';')
Air
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9466         NaN       NaN    NaN          NaN       NaN      NaN
# 9467         NaN       NaN    NaN          NaN       NaN      NaN
# 9468         NaN       NaN    NaN          NaN       NaN      NaN
# 9469         NaN       NaN    NaN          NaN       NaN      NaN
# 9470         NaN       NaN    NaN          NaN       NaN      NaN
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9466            NaN      NaN           NaN      NaN           NaN
# 9467            NaN      NaN           NaN      NaN           NaN
# 9468            NaN      NaN           NaN      NaN           NaN
# 9469            NaN      NaN           NaN      NaN           NaN
# 9470            NaN      NaN           NaN      NaN           NaN
#
#       PT08.S5(O3)     T    RH      AH  Unnamed: 15  Unnamed: 16
# 0          1268.0  13,6  48,9  0,7578          NaN          NaN
# 1           972.0  13,3  47,7  0,7255          NaN          NaN
# 2          1074.0  11,9  54,0  0,7502          NaN          NaN
# 3          1203.0  11,0  60,0  0,7867          NaN          NaN
# 4          1110.0  11,2  59,6  0,7888          NaN          NaN
# ...           ...   ...   ...     ...          ...          ...
# 9466          NaN   NaN   NaN     NaN          NaN          NaN
# 9467          NaN   NaN   NaN     NaN          NaN          NaN
# 9468          NaN   NaN   NaN     NaN          NaN          NaN
# 9469          NaN   NaN   NaN     NaN          NaN          NaN
# 9470          NaN   NaN   NaN     NaN          NaN          NaN
#
# [9471 rows x 17 columns]

# %%
Heart = pd.read_csv(r'/home/pict/Downloads/Heart.csv', sep = ',')
Heart
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope   Ca        Thal  AHD
# 0        0      2.3      3  0.0       fixed   No
# 1        1      1.5      2  3.0      normal  Yes
# 2        1      2.6      2  2.0  reversable  Yes
# 3        0      3.5      3  0.0      normal   No
# 4        0      1.4      1  0.0      normal   No
# ..     ...      ...    ...  ...         ...  ...
# 298      0      1.2      2  0.0  reversable  Yes
# 299      0      3.4      2  2.0  reversable  Yes
# 300      1      1.2      2  1.0  reversable  Yes
# 301      0      0.0      2  1.0      normal  Yes
# 302      0      0.0      1  NaN      normal   No
#
# [303 rows x 15 columns]

# %% [markdown]
# # Data Cleaning

# %%
# Checking for null values in our dataset
Air.isnull().sum()
# Out:
# Date              114
# Time              114
# CO(GT)            114
# PT08.S1(CO)       114
# NMHC(GT)          114
# C6H6(GT)          114
# PT08.S2(NMHC)     114
# NOx(GT)           114
# PT08.S3(NOx)      114
# NO2(GT)           114
# PT08.S4(NO2)      114
# PT08.S5(O3)       114
# T                 114
# RH                114
# AH                114
# Unnamed: 15      9471
# Unnamed: 16      9471
# dtype: int64

# %%
# Removing columns containing only null values
Air.drop(['Unnamed: 15', 'Unnamed: 16'], axis=1, inplace=True)

# %%
# Removing rows containing only null values
Air1 = Air.loc[ 0:9356, :]
Air1
# Out:
#             Date      Time CO(GT)  PT08.S1(CO)  NMHC(GT) C6H6(GT)  \
# 0     10/03/2004  18.00.00    2,6       1360.0     150.0     11,9
# 1     10/03/2004  19.00.00      2       1292.0     112.0      9,4
# 2     10/03/2004  20.00.00    2,2       1402.0      88.0      9,0
# 3     10/03/2004  21.00.00    2,2       1376.0      80.0      9,2
# 4     10/03/2004  22.00.00    1,6       1272.0      51.0      6,5
# ...          ...       ...    ...          ...       ...      ...
# 9352  04/04/2005  10.00.00    3,1       1314.0    -200.0     13,5
# 9353  04/04/2005  11.00.00    2,4       1163.0    -200.0     11,4
# 9354  04/04/2005  12.00.00    2,4       1142.0    -200.0     12,4
# 9355  04/04/2005  13.00.00    2,1       1003.0    -200.0      9,5
# 9356  04/04/2005  14.00.00    2,2       1071.0    -200.0     11,9
#
#       PT08.S2(NMHC)  NOx(GT)  PT08.S3(NOx)  NO2(GT)  PT08.S4(NO2)  \
# 0            1046.0    166.0        1056.0    113.0        1692.0
# 1             955.0    103.0        1174.0     92.0        1559.0
# 2             939.0    131.0        1140.0    114.0        1555.0
# 3             948.0    172.0        1092.0    122.0        1584.0
# 4             836.0    131.0        1205.0    116.0        1490.0
# ...             ...      ...           ...      ...           ...
# 9352         1101.0    472.0         539.0    190.0        1374.0
# 9353         1027.0    353.0         604.0    179.0        1264.0
# 9354         1063.0    293.0         603.0    175.0        1241.0
# 9355          961.0    235.0         702.0    156.0        1041.0
# 9356         1047.0    265.0         654.0    168.0        1129.0
#
#       PT08.S5(O3)     T    RH      AH
# 0          1268.0  13,6  48,9  0,7578
# 1           972.0  13,3  47,7  0,7255
# 2          1074.0  11,9  54,0  0,7502
# 3          1203.0  11,0  60,0  0,7867
# 4          1110.0  11,2  59,6  0,7888
# ...           ...   ...   ...     ...
# 9352       1729.0  21,9  29,3  0,7568
# 9353       1269.0  24,3  23,7  0,7119
# 9354       1092.0  26,9  18,3  0,6406
# 9355        770.0  28,3  13,5  0,5139
# 9356        816.0  28,5  13,1  0,5028
#
# [9357 rows x 15 columns]

# %%
# Here we can see that our data now has no null values
Air1.isnull().sum()
# Out:
# Date             0
# Time             0
# CO(GT)           0
# PT08.S1(CO)      0
# NMHC(GT)         0
# C6H6(GT)         0
# PT08.S2(NMHC)    0
# NOx(GT)          0
# PT08.S3(NOx)     0
# NO2(GT)          0
# PT08.S4(NO2)     0
# PT08.S5(O3)      0
# T                0
# RH               0
# AH               0
# dtype: int64

# %%
# Checking if null values are present in our dataset
Heart.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            4
# Thal          2
# AHD           0
# dtype: int64

# %%
Heart['Ca'].fillna(value = Heart['Ca'].mean(), inplace = True)
Heart['Thal'].fillna(value = Heart['Thal'].ffill(), inplace = True)

# %%
# Here we can see that we have removed all null entries
Heart.isnull().sum()
# Out:
# Unnamed: 0    0
# Age           0
# Sex           0
# ChestPain     0
# RestBP        0
# Chol          0
# Fbs           0
# RestECG       0
# MaxHR         0
# ExAng         0
# Oldpeak       0
# Slope         0
# Ca            0
# Thal          0
# AHD           0
# dtype: int64

# %%
# Checking for outliers in Air dataset
plt.figure(figsize = (15,15))
Air1.boxplot()
# Out:
# <AxesSubplot:>

# %%
# Checking outliers for Heart dataset
plt.figure(figsize = (15,15))
Heart.boxplot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ## Data Integration

# %%
# First we create subset of heart on the basis of sex
Heart_M = Heart[Heart['Sex']==1]
Heart_M.shape
# Out:
# (206, 15)

# %%
Heart_F = Heart[Heart['Sex']==0]
Heart_F.shape
# Out:
# (97, 15)

# %%
# We combine both of them together
Heart_dataframe = pd.concat([Heart_M, Heart_F])
Heart_dataframe.shape
# Out:
# (303, 15)

# %%
dataframe = pd.concat([Heart, Air1])

# %%
dataframe
# Out:
#       Unnamed: 0   Age  Sex     ChestPain  RestBP   Chol  Fbs  RestECG  MaxHR  \
# 0            1.0  63.0  1.0       typical   145.0  233.0  1.0      2.0  150.0
# 1            2.0  67.0  1.0  asymptomatic   160.0  286.0  0.0      2.0  108.0
# 2            3.0  67.0  1.0  asymptomatic   120.0  229.0  0.0      2.0  129.0
# 3            4.0  37.0  1.0    nonanginal   130.0  250.0  0.0      0.0  187.0
# 4            5.0  41.0  0.0    nontypical   130.0  204.0  0.0      2.0  172.0
# ...          ...   ...  ...           ...     ...    ...  ...      ...    ...
# 9352         NaN   NaN  NaN           NaN     NaN    NaN  NaN      NaN    NaN
# 9353         NaN   NaN  NaN           NaN     NaN    NaN  NaN      NaN    NaN
# 9354         NaN   NaN  NaN           NaN     NaN    NaN  NaN      NaN    NaN
# 9355         NaN   NaN  NaN           NaN     NaN    NaN  NaN      NaN    NaN
# 9356         NaN   NaN  NaN           NaN     NaN    NaN  NaN      NaN    NaN
#
#       ExAng  ...  C6H6(GT)  PT08.S2(NMHC)  NOx(GT) PT08.S3(NOx) NO2(GT)  \
# 0       0.0  ...       NaN            NaN      NaN          NaN     NaN
# 1       1.0  ...       NaN            NaN      NaN          NaN     NaN
# 2       1.0  ...       NaN            NaN      NaN          NaN     NaN
# 3       0.0  ...       NaN            NaN      NaN          NaN     NaN
# 4       0.0  ...       NaN            NaN      NaN          NaN     NaN
# ...     ...  ...       ...            ...      ...          ...     ...
# 9352    NaN  ...      13,5         1101.0    472.0        539.0   190.0
# 9353    NaN  ...      11,4         1027.0    353.0        604.0   179.0
# 9354    NaN  ...      12,4         1063.0    293.0        603.0   175.0
# 9355    NaN  ...       9,5          961.0    235.0        702.0   156.0
# 9356    NaN  ...      11,9         1047.0    265.0        654.0   168.0
#
#      PT08.S4(NO2) PT08.S5(O3)     T    RH      AH
# 0             NaN         NaN   NaN   NaN     NaN
# 1             NaN         NaN   NaN   NaN     NaN
# 2             NaN         NaN   NaN   NaN     NaN
# 3             NaN         NaN   NaN   NaN     NaN
# 4             NaN         NaN   NaN   NaN     NaN
# ...           ...         ...   ...   ...     ...
# 9352       1374.0      1729.0  21,9  29,3  0,7568
# 9353       1264.0      1269.0  24,3  23,7  0,7119
# 9354       1241.0      1092.0  26,9  18,3  0,6406
# 9355       1041.0       770.0  28,3  13,5  0,5139
# 9356       1129.0       816.0  28,5  13,1  0,5028
#
# [9660 rows x 30 columns]

# %%
dataframe.head()
# Out:
#    Unnamed: 0   Age  Sex     ChestPain  RestBP   Chol  Fbs  RestECG  MaxHR  \
# 0         1.0  63.0  1.0       typical   145.0  233.0  1.0      2.0  150.0
# 1         2.0  67.0  1.0  asymptomatic   160.0  286.0  0.0      2.0  108.0
# 2         3.0  67.0  1.0  asymptomatic   120.0  229.0  0.0      2.0  129.0
# 3         4.0  37.0  1.0    nonanginal   130.0  250.0  0.0      0.0  187.0
# 4         5.0  41.0  0.0    nontypical   130.0  204.0  0.0      2.0  172.0
#
#    ExAng  ...  C6H6(GT)  PT08.S2(NMHC)  NOx(GT) PT08.S3(NOx) NO2(GT)  \
# 0    0.0  ...       NaN            NaN      NaN          NaN     NaN
# 1    1.0  ...       NaN            NaN      NaN          NaN     NaN
# 2    1.0  ...       NaN            NaN      NaN          NaN     NaN
# 3    0.0  ...       NaN            NaN      NaN          NaN     NaN
# 4    0.0  ...       NaN            NaN      NaN          NaN     NaN
#
#   PT08.S4(NO2) PT08.S5(O3)    T   RH   AH
# 0          NaN         NaN  NaN  NaN  NaN
# 1          NaN         NaN  NaN  NaN  NaN
# 2          NaN         NaN  NaN  NaN  NaN
# 3          NaN         NaN  NaN  NaN  NaN
# 4          NaN         NaN  NaN  NaN  NaN
#
# [5 rows x 30 columns]

# %%
dataframe.tail()
# Out:
#       Unnamed: 0  Age  Sex ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 9352         NaN  NaN  NaN       NaN     NaN   NaN  NaN      NaN    NaN
# 9353         NaN  NaN  NaN       NaN     NaN   NaN  NaN      NaN    NaN
# 9354         NaN  NaN  NaN       NaN     NaN   NaN  NaN      NaN    NaN
# 9355         NaN  NaN  NaN       NaN     NaN   NaN  NaN      NaN    NaN
# 9356         NaN  NaN  NaN       NaN     NaN   NaN  NaN      NaN    NaN
#
#       ExAng  ...  C6H6(GT)  PT08.S2(NMHC)  NOx(GT) PT08.S3(NOx) NO2(GT)  \
# 9352    NaN  ...      13,5         1101.0    472.0        539.0   190.0
# 9353    NaN  ...      11,4         1027.0    353.0        604.0   179.0
# 9354    NaN  ...      12,4         1063.0    293.0        603.0   175.0
# 9355    NaN  ...       9,5          961.0    235.0        702.0   156.0
# 9356    NaN  ...      11,9         1047.0    265.0        654.0   168.0
#
#      PT08.S4(NO2) PT08.S5(O3)     T    RH      AH
# 9352       1374.0      1729.0  21,9  29,3  0,7568
# 9353       1264.0      1269.0  24,3  23,7  0,7119
# 9354       1241.0      1092.0  26,9  18,3  0,6406
# 9355       1041.0       770.0  28,3  13,5  0,5139
# 9356       1129.0       816.0  28,5  13,1  0,5028
#
# [5 rows x 30 columns]

# %% [markdown]
# ## Data Transformation

# %% [markdown]
# ## We need to do certain transformation to build the model

# %%
Heart1 = pd.read_csv(r'/home/pict/Downloads/Heart.csv', sep = ',')

# %%
Heart1.loc[Heart1["ChestPain"] == "asymptomatic", "ChestPain"] = 0
Heart1.loc[Heart1["ChestPain"] == "nontypical", "ChestPain"] = 1
Heart1.loc[Heart1["ChestPain"] == "nonanginal", "ChestPain"] = 2
Heart1.loc[Heart1["ChestPain"] == "typical", "ChestPain"] = 3

# %%
Heart1.loc[Heart1["Thal"] == "normal", "Thal"] = 1
Heart1.loc[Heart1["Thal"] == "fixed", "Thal"] = 2
Heart1.loc[Heart1["Thal"] == "reversable", "Thal"] = 3

# %%
Heart1.loc[Heart1["AHD"] == "No", "AHD"] = 0
Heart1.loc[Heart1["AHD"] == "Yes", "AHD"] = 1

# %%
Heart
# Out:
#      Unnamed: 0  Age  Sex     ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  \
# 0             1   63    1       typical     145   233    1        2    150
# 1             2   67    1  asymptomatic     160   286    0        2    108
# 2             3   67    1  asymptomatic     120   229    0        2    129
# 3             4   37    1    nonanginal     130   250    0        0    187
# 4             5   41    0    nontypical     130   204    0        2    172
# ..          ...  ...  ...           ...     ...   ...  ...      ...    ...
# 298         299   45    1       typical     110   264    0        0    132
# 299         300   68    1  asymptomatic     144   193    1        0    141
# 300         301   57    1  asymptomatic     130   131    0        0    115
# 301         302   57    0    nontypical     130   236    0        2    174
# 302         303   38    1    nonanginal     138   175    0        0    173
#
#      ExAng  Oldpeak  Slope        Ca        Thal  AHD
# 0        0      2.3      3  0.000000       fixed   No
# 1        1      1.5      2  3.000000      normal  Yes
# 2        1      2.6      2  2.000000  reversable  Yes
# 3        0      3.5      3  0.000000      normal   No
# 4        0      1.4      1  0.000000      normal   No
# ..     ...      ...    ...       ...         ...  ...
# 298      0      1.2      2  0.000000  reversable  Yes
# 299      0      3.4      2  2.000000  reversable  Yes
# 300      1      1.2      2  1.000000  reversable  Yes
# 301      0      0.0      2  1.000000      normal  Yes
# 302      0      0.0      1  0.672241      normal   No
#
# [303 rows x 15 columns]

# %%
Heart1
# Out:
#      Unnamed: 0  Age  Sex ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  \
# 0             1   63    1         3     145   233    1        2    150      0
# 1             2   67    1         0     160   286    0        2    108      1
# 2             3   67    1         0     120   229    0        2    129      1
# 3             4   37    1         2     130   250    0        0    187      0
# 4             5   41    0         1     130   204    0        2    172      0
# ..          ...  ...  ...       ...     ...   ...  ...      ...    ...    ...
# 298         299   45    1         3     110   264    0        0    132      0
# 299         300   68    1         0     144   193    1        0    141      0
# 300         301   57    1         0     130   131    0        0    115      1
# 301         302   57    0         1     130   236    0        2    174      0
# 302         303   38    1         2     138   175    0        0    173      0
#
#      Oldpeak  Slope   Ca Thal AHD
# 0        2.3      3  0.0    2   0
# 1        1.5      2  3.0    1   1
# 2        2.6      2  2.0    3   1
# 3        3.5      3  0.0    1   0
# 4        1.4      1  0.0    1   0
# ..       ...    ...  ...  ...  ..
# 298      1.2      2  0.0    3   1
# 299      3.4      2  2.0    3   1
# 300      1.2      2  1.0    3   1
# 301      0.0      2  1.0    1   1
# 302      0.0      1  NaN    1   0
#
# [303 rows x 15 columns]

# %% [markdown]
# ## Error Correcting

# %%
Heart1 = Heart1.dropna()

# %%
Heart1.shape
# Out:
# (297, 15)

# %%
Heart1 = Heart1.drop(Heart1.columns[0], axis=1)

# %%
Heart1.shape
# Out:
# (297, 14)

# %%
Heart1
# Out:
#      Age  Sex ChestPain  RestBP  Chol  Fbs  RestECG  MaxHR  ExAng  Oldpeak  \
# 0     63    1         3     145   233    1        2    150      0      2.3
# 1     67    1         0     160   286    0        2    108      1      1.5
# 2     67    1         0     120   229    0        2    129      1      2.6
# 3     37    1         2     130   250    0        0    187      0      3.5
# 4     41    0         1     130   204    0        2    172      0      1.4
# ..   ...  ...       ...     ...   ...  ...      ...    ...    ...      ...
# 297   57    0         0     140   241    0        0    123      1      0.2
# 298   45    1         3     110   264    0        0    132      0      1.2
# 299   68    1         0     144   193    1        0    141      0      3.4
# 300   57    1         0     130   131    0        0    115      1      1.2
# 301   57    0         1     130   236    0        2    174      0      0.0
#
#      Slope   Ca Thal AHD
# 0        3  0.0    2   0
# 1        2  3.0    1   1
# 2        2  2.0    3   1
# 3        3  0.0    1   0
# 4        1  0.0    1   0
# ..     ...  ...  ...  ..
# 297      2  0.0    3   1
# 298      2  0.0    3   1
# 299      2  2.0    3   1
# 300      2  1.0    3   1
# 301      2  1.0    1   1
#
# [297 rows x 14 columns]

# %% [markdown]
# ## Data Model Building

# %%
pip install scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in /home/pict/.local/lib/python3.8/site-packages (1.0.2)
# Requirement already satisfied: numpy>=1.14.6 in /home/pict/.local/lib/python3.8/site-packages (from scikit-learn) (1.22.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/pict/.local/lib/python3.8/site-packages (from scikit-learn) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/pict/.local/lib/python3.8/site-packages (from scikit-learn) (1.1.0)
# Requirement already satisfied: scipy>=1.1.0 in /usr/lib/python3/dist-packages (from scikit-learn) (1.3.3)
# WARNING: You are using pip version 22.0.3; however, version 22.0.4 is available.
# You should consider upgrading via the '/usr/bin/python3 -m pip install --upgrade pip' command.
# Note: you may need to restart the kernel to use updated packages.

# %%
from sklearn.model_selection import train_test_split

predictors = Heart1.drop("AHD",axis=1)
target = Heart1["AHD"]

X_train,X_test,Y_train,Y_test = train_test_split(predictors,target,test_size=0.20,random_state=0)

# %%
X_train.shape
# Out:
# (237, 13)

# %%
X_test.shape
# Out:
# (60, 13)

# %%
Y_train.shape
# Out:
# (237,)

# %%
Y_test.shape
# Out:
# (60,)

# %%
from sklearn.metrics import accuracy_score

from sklearn.linear_model import LogisticRegression

lr = LogisticRegression()

lr.fit(X_train,Y_train)

Y_pred_lr = lr.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [37], in <cell line: 7>()
#       3 from sklearn.linear_model import LogisticRegression
#       5 lr = LogisticRegression()
# ----> 7 lr.fit(X_train,Y_train)
#       9 Y_pred_lr = lr.predict(X_test)
#
# File ~/.local/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:1516, in LogisticRegression.fit(self, X, y, sample_weight)
#    1506     _dtype = [np.float64, np.float32]
#    1508 X, y = self._validate_data(
#    1509     X,
#    1510     y,
#    (...)
#    1514     accept_large_sparse=solver not in ["liblinear", "sag", "saga"],
#    1515 )
# -> 1516 check_classification_targets(y)
#    1517 self.classes_ = np.unique(y)
#    1519 multi_class = _check_multi_class(self.multi_class, solver, len(self.classes_))
#
# File ~/.local/lib/python3.8/site-packages/sklearn/utils/multiclass.py:197, in check_classification_targets(y)
#     189 y_type = type_of_target(y)
#     190 if y_type not in [
#     191     "binary",
#     192     "multiclass",
#    (...)
#     195     "multilabel-sequences",
#     196 ]:
# --> 197     raise ValueError("Unknown label type: %r" % y_type)
#
# ValueError: Unknown label type: 'unknown'

# %%
Y_pred_lr.shape

# %%
score_lr = round(accuracy_score(Y_pred_lr,Y_test)*100,2)

print("The accuracy score achieved using Logistic Regression is: "+str(score_lr)+" %")
